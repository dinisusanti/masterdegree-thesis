# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("Jisdoredit1.csv", parse_dates = True, index_col = 0)
train = df['Rate'][:505].to_numpy()
test = df['Rate'][500:].to_numpy()
sc = MinMaxScaler(feature_range=(0,1))
train = sc.fit_transform(train.reshape(-1,1))
test = sc.transform(test.reshape(-1,1))

def data_preparation(data):
    x = []
    y = []
    
    for i in range(5, len(data)):
        x.append(data[i-5:i, 0])
        y.append(data[i])
    x, y = np.array(x), np.array(y)
    
    x = np.reshape(x, (x.shape[0], x.shape[1], 1))
    return x, y

x_train, y_train = data_preparation(train)
x_test, y_test = data_preparation(test)

model = Sequential()
model.add(LSTM(units=5, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(units=5))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer = 'adam', loss ='mean_squared_error', metrics=['accuracy'])
model.fit(x_train, y_train, epochs = 50, batch_size = 4)
# Out:
# Epoch 1/50
# 125/125 [==============================] - 11s 15ms/step - loss: 0.0240 - accuracy: 0.0040
# Epoch 2/50
# 125/125 [==============================] - 3s 27ms/step - loss: 0.0115 - accuracy: 0.0040
# Epoch 3/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0080 - accuracy: 0.0020
# Epoch 4/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0056 - accuracy: 0.0040
# Epoch 5/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0067 - accuracy: 0.0040
# Epoch 6/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0062 - accuracy: 0.0040
# Epoch 7/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0062 - accuracy: 0.0040
# Epoch 8/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0059 - accuracy: 0.0040
# Epoch 9/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0065 - accuracy: 0.0040
# Epoch 10/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0048 - accuracy: 0.0040
# Epoch 11/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0043 - accuracy: 0.0040
# Epoch 12/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0045 - accuracy: 0.0040
# Epoch 13/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0041 - accuracy: 0.0040
# Epoch 14/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0051 - accuracy: 0.0040
# Epoch 15/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0039 - accuracy: 0.0040
# Epoch 16/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0034 - accuracy: 0.0040
# Epoch 17/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0040 - accuracy: 0.0040
# Epoch 18/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0043 - accuracy: 0.0040
# Epoch 19/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0040 - accuracy: 0.0040
# Epoch 20/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0051 - accuracy: 0.0040
# Epoch 21/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0043 - accuracy: 0.0040
# Epoch 22/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0033 - accuracy: 0.0040
# Epoch 23/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0036 - accuracy: 0.0040
# Epoch 24/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0045 - accuracy: 0.0020
# Epoch 25/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0041 - accuracy: 0.0040
# Epoch 26/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0034 - accuracy: 0.0040
# Epoch 27/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0038 - accuracy: 0.0040
# Epoch 28/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0035 - accuracy: 0.0040
# Epoch 29/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0034 - accuracy: 0.0040
# Epoch 30/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0036 - accuracy: 0.0040
# Epoch 31/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0032 - accuracy: 0.0040
# Epoch 32/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0033 - accuracy: 0.0040
# Epoch 33/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0035 - accuracy: 0.0040
# Epoch 34/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0037 - accuracy: 0.0040
# Epoch 35/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0038 - accuracy: 0.0040
# Epoch 36/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0032 - accuracy: 0.0040
# Epoch 37/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0032 - accuracy: 0.0040
# Epoch 38/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0041 - accuracy: 0.0040
# Epoch 39/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0034 - accuracy: 0.0040
# Epoch 40/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0029 - accuracy: 0.0040
# Epoch 41/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0033 - accuracy: 0.0040
# Epoch 42/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0034 - accuracy: 0.0040
# Epoch 43/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0034 - accuracy: 0.0040
# Epoch 44/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0038 - accuracy: 0.0040
# Epoch 45/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0040 - accuracy: 0.0040
# Epoch 46/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0029 - accuracy: 0.0040
# Epoch 47/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0032 - accuracy: 0.0040
# Epoch 48/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0036 - accuracy: 0.0040
# Epoch 49/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0032 - accuracy: 0.0040
# Epoch 50/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0037 - accuracy: 0.0040

# %%
y_pred = model.predict(x_test)
y_pred.shape
# Out:
# 2/2 [==============================] - 0s 15ms/step
# (39, 1)

# %%
fig, ax = plt.subplots()
ax.plot(y_pred)
ax.plot(y_test, c = 'r')

# %%
y_pred = sc.inverse_transform(y_pred)
ig, ax = plt.subplots()
y_real = df['Rate'].to_numpy()
ax.plot(y_real[505:], color ='b', label = 'Real Rate')
ax.plot(y_pred, color ='r', label = 'Forcaste Rate')

# %%
pd.options.mode.chained_assignment = None

dtrain = df[:505]
valid = df[505:]
valid['Predictions'] = y_pred

plt.figure(figsize=(13,5))
plt.title('USD/IDR Exchange Rate Forecast During COVID-19 Pandemic')
plt.xlabel('Date', fontsize = 13)
plt.ylabel('Exchange Rate', fontsize = 13)
plt.plot(dtrain['Rate'])
plt.plot(valid[['Rate', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc = 'upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
newtest = df['Rate'][505:].to_numpy()
mse = np.square(np.subtract(newtest,y_pred)).mean()
mse
# Out:
# 2229.529459568327

# %%
rmse = np.sqrt(np.mean((y_pred - newtest)**2))
rmse
# Out:
# 47.2178934257801

# %%
rmse1 = np.sqrt(mse)
rmse1
# Out:
# 47.2178934257801

# %%
mape = np.mean(np.abs((newtest - y_pred)/ newtest))*100
mape
# Out:
# 0.26415677468855736

# %%
plt.figure(figsize=(13,5))
plt.title('USD/IDR Exchange Rate Forecast During COVID-19 Pandemic')
plt.xlabel('Date', fontsize = 13)
plt.ylabel('Exchange Rate', fontsize = 13)
plt.plot(valid[['Rate', 'Predictions']])
plt.legend(['Real', 'Predictions'], loc = 'upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
