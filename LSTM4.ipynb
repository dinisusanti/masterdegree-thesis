# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("Jisdoredit1.csv", parse_dates = True, index_col = 0)
train = df['Rate'][:505].to_numpy()
test = df['Rate'][505:].to_numpy()
sc = MinMaxScaler(feature_range=(0,1))
train = sc.fit_transform(train.reshape(-1,1))
test = sc.transform(test.reshape(-1,1))

def data_preparation(data):
    x = []
    y = []
    
    for i in range(10, len(data)):
        x.append(data[i-10:i, 0])
        y.append(data[i])
    x, y = np.array(x), np.array(y)
    
    x = np.reshape(x, (x.shape[0], x.shape[1], 1))
    return x, y

x_train, y_train = data_preparation(train)
x_test, y_test = data_preparation(test)

model = Sequential()
model.add(LSTM(units=5, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(LSTM(units=5))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer = 'adam', loss ='mean_squared_error', metrics=['accuracy'])
model.fit(x_train, y_train, epochs = 50, batch_size = 4)
# Out:
# Epoch 1/50
# 124/124 [==============================] - 10s 20ms/step - loss: 0.0191 - accuracy: 0.0020
# Epoch 2/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0106 - accuracy: 0.0040
# Epoch 3/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0097 - accuracy: 0.0040
# Epoch 4/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0090 - accuracy: 0.0040
# Epoch 5/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0085 - accuracy: 0.0040
# Epoch 6/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0072 - accuracy: 0.0040
# Epoch 7/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0077 - accuracy: 0.0040
# Epoch 8/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0071 - accuracy: 0.0020
# Epoch 9/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0068 - accuracy: 0.0040
# Epoch 10/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0064 - accuracy: 0.0040
# Epoch 11/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0061 - accuracy: 0.0040
# Epoch 12/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0051 - accuracy: 0.0040
# Epoch 13/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0061 - accuracy: 0.0040
# Epoch 14/50
# 124/124 [==============================] - 3s 20ms/step - loss: 0.0055 - accuracy: 0.0040
# Epoch 15/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0048 - accuracy: 0.0040
# Epoch 16/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0040 - accuracy: 0.0040
# Epoch 17/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0049 - accuracy: 0.0040
# Epoch 18/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0047 - accuracy: 0.0040
# Epoch 19/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0038 - accuracy: 0.0040
# Epoch 20/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0048 - accuracy: 0.0020
# Epoch 21/50
# 124/124 [==============================] - 3s 21ms/step - loss: 0.0044 - accuracy: 0.0040
# Epoch 22/50
# 124/124 [==============================] - 3s 20ms/step - loss: 0.0037 - accuracy: 0.0040
# Epoch 23/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0046 - accuracy: 0.0040
# Epoch 24/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0033 - accuracy: 0.0040
# Epoch 25/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0037 - accuracy: 0.0040
# Epoch 26/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0039 - accuracy: 0.0040
# Epoch 27/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0037 - accuracy: 0.0040
# Epoch 28/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0045 - accuracy: 0.0040
# Epoch 29/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0032 - accuracy: 0.0040
# Epoch 30/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0036 - accuracy: 0.0040
# Epoch 31/50
# 124/124 [==============================] - 3s 21ms/step - loss: 0.0034 - accuracy: 0.0040
# Epoch 32/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0034 - accuracy: 0.0040
# Epoch 33/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0034 - accuracy: 0.0040
# Epoch 34/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0030 - accuracy: 0.0040
# Epoch 35/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0029 - accuracy: 0.0040
# Epoch 36/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0035 - accuracy: 0.0040
# Epoch 37/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0040 - accuracy: 0.0020
# Epoch 38/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0031 - accuracy: 0.0040
# Epoch 39/50
# 124/124 [==============================] - 3s 20ms/step - loss: 0.0031 - accuracy: 0.0040
# Epoch 40/50
# 124/124 [==============================] - 3s 21ms/step - loss: 0.0031 - accuracy: 0.0040
# Epoch 41/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0039 - accuracy: 0.0040
# Epoch 42/50
# 124/124 [==============================] - 3s 20ms/step - loss: 0.0033 - accuracy: 0.0040
# Epoch 43/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0031 - accuracy: 0.0040
# Epoch 44/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0031 - accuracy: 0.0040
# Epoch 45/50
# 124/124 [==============================] - 2s 19ms/step - loss: 0.0037 - accuracy: 0.0020
# Epoch 46/50
# 124/124 [==============================] - 3s 20ms/step - loss: 0.0030 - accuracy: 0.0040
# Epoch 47/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0031 - accuracy: 0.0040
# Epoch 48/50
# 124/124 [==============================] - 3s 20ms/step - loss: 0.0034 - accuracy: 0.0040
# Epoch 49/50
# 124/124 [==============================] - 2s 20ms/step - loss: 0.0041 - accuracy: 0.0040
# Epoch 50/50
# 124/124 [==============================] - 3s 27ms/step - loss: 0.0025 - accuracy: 0.0040

# %%
y_pred = model.predict(x_test)
fig, ax = plt.subplots()
ax.plot(y_pred)
ax.plot(y_test, c = 'r')
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
y_pred = sc.inverse_transform(y_pred)
ig, ax = plt.subplots()
y_real = df['Rate'].to_numpy()
ax.plot(y_real[505:], color ='b', label = 'Real Rate')
ax.plot(y_pred, color ='r', label = 'Forcaste Rate')
